# %%
import pandas as pd
import numpy as np

data = {
    'ID': [1,2,3,4,5],
    'Name': ['Asha','Ravi','Neha','Aman','Asha'],
    'Age': [20,22,21,23,20],
    'Marks': [70,80,np.nan,90,70],
    'Gender': ['F','M','F','M','F'],
    'Course': ['Data Science','AI','AI','Data Science','Data Science']
}

df = pd.DataFrame(data)
print(df)
# Out:
#    ID  Name  Age  Marks Gender        Course
# 0   1  Asha   20   70.0      F  Data Science
# 1   2  Ravi   22   80.0      M            AI
# 2   3  Neha   21    NaN      F            AI
# 3   4  Aman   23   90.0      M  Data Science
# 4   5  Asha   20   70.0      F  Data Science

# %%
df['Marks'].fillna(df['Marks'].mean(), inplace=True)

print(df)
# Out:
#    ID  Name  Age  Marks Gender        Course
# 0   1  Asha   20   70.0      F  Data Science
# 1   2  Ravi   22   80.0      M            AI
# 2   3  Neha   21   77.5      F            AI
# 3   4  Aman   23   90.0      M  Data Science
# 4   5  Asha   20   70.0      F  Data Science
# /tmp/ipykernel_219/1176173551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(df['Marks'].mean(), inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

print(df)
# Out:
#    ID  Name  Age  Marks  Gender        Course
# 0   1  Asha   20   70.0       0  Data Science
# 1   2  Ravi   22   80.0       1            AI
# 2   3  Neha   21   77.5       0            AI
# 3   4  Aman   23   90.0       1  Data Science
# 4   5  Asha   20   70.0       0  Data Science

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['Marks_MinMax'] = scaler.fit_transform(df[['Marks']])

print(df)
# Out:
#    ID  Name  Age  Marks  Gender        Course  Marks_MinMax
# 0   1  Asha   20   70.0       0  Data Science         0.000
# 1   2  Ravi   22   80.0       1            AI         0.500
# 2   3  Neha   21   77.5       0            AI         0.375
# 3   4  Aman   23   90.0       1  Data Science         1.000
# 4   5  Asha   20   70.0       0  Data Science         0.000

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df['Age_Zscore'] = scaler.fit_transform(df[['Age']])

print(df)
# Out:
#    ID  Name  Age  Marks  Gender        Course  Marks_MinMax  Age_Zscore
# 0   1  Asha   20   70.0       0  Data Science         0.000   -1.028992
# 1   2  Ravi   22   80.0       1            AI         0.500    0.685994
# 2   3  Neha   21   77.5       0            AI         0.375   -0.171499
# 3   4  Aman   23   90.0       1  Data Science         1.000    1.543487
# 4   5  Asha   20   70.0       0  Data Science         0.000   -1.028992
